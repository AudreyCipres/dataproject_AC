# %%
pip install pandas matplotlib numpy
# Out:
# ...
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: C:\Users\audre\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (10, 5)

# %%
if os.path.isfile("2020-biannual-two-incident-report.csv"):
    filepath = "2020-biannual-two-incident-report.csv"
    print("loading from file")
else:
    filepath = "https://data.cese.nsw.gov.au/data/dataset/incident-reports-nsw-government-schools/resource/736931f6-0806-4d78-9a04-c9b229ece8dd/download/2020-biannual-incident-report.csv"
    print("loading from the internet")

# filepath = "2020-biannual-two-incident-report.csv" "https://data.cese.nsw.gov.au/data/dataset/incident-reports-nsw-government-schools/resource/736931f6-0806-4d78-9a04-c9b229ece8dd"

id_data = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
id_data.shape
# Out:
# (1022, 12)

# %%
id_data.head()
# Out:
#      Case Number Date/Time Opened   Term  Incident Group  \
# 0  S-2020-282979  6/07/2020 10:24  Term 3       Violence
# 1  S-2020-282985  6/07/2020 10:41  Term 3       Violence
# 2  S-2020-283017  6/07/2020 11:18  Term 3       Violence
# 3  S-2020-283070  6/07/2020 13:22  Term 3       Violence
# 4  S-2020-283107  6/07/2020 14:54  Term 3       Violence
#
#            Operational Directorate Principal Network Name  Primary Category  \
# 0                   Regional South             Shoalhaven  Indecent Assault
# 1               Metropolitan South             Botany Bay  Indecent Assault
# 2                   Regional North   Lake Macquarie North  Indecent Assault
# 3  Metropolitan South & South West        Chipping Norton  Indecent Assault
# 4                   Regional North          Mooney Mooney  Indecent Assault
#
#   Primary Sub-Category Secondary Category  \
# 0                  NaN                NaN
# 1                  NaN                NaN
# ...

# %%
id_data.columns
# Out:
# Index(['Case Number', 'Date/Time Opened', 'Term ', 'Incident Group',
#        'Operational Directorate', 'Principal Network Name', 'Primary Category',
#        'Primary Sub-Category', 'Secondary Category',
#        'Summary of the Incident (External Distribution)',
#        'Incident Priority Rating', 'Incident Occurred'],
#       dtype='object')

# %%
row_one = id_data.iloc[1]
row_one
# Out:
# Case Number                                                                            S-2020-282985
# Date/Time Opened                                                                     6/07/2020 10:41
# Term                                                                                          Term 3
# Incident Group                                                                              Violence
# Operational Directorate                                                           Metropolitan South
# Principal Network Name                                                                    Botany Bay
# Primary Category                                                                    Indecent Assault
# Primary Sub-Category                                                                             NaN
# Secondary Category                                                                               NaN
# ...

# %%
row_one["Incident Group"]
# Out:
# 'Violence'

# %%
id_data["Operational Directorate"].value_counts()
# Out:
# Metropolitan South & South West    157
# Regional South                     149
# Regional North                     134
# Metropolitan North                 126
# Metropolitan South                 120
# Regional North and West            120
# Rural South and West               119
# Rural North                         81
# Connected Communities               16
# Name: Operational Directorate, dtype: int64

# %%
id_data["Principal Network Name"].value_counts()
# Out:
# Campbelltown     31
# South Coast      26
# Glenfield        24
# Fairfield        21
# Mount Druitt     21
#                  ..
# Glenrock          2
# Hornsby           2
# The Beaches       2
# Beverly Hills     2
# Barwon            1
# Name: Principal Network Name, Length: 112, dtype: int64

# %%
capped_idvc = id_data["Principal Network Name"].value_counts()
capped_idvc[capped_idvc < 10].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
id_data["Incident Group"].value_counts().plot(kind="bar")
plt.title("Number of instances for each incident category")
plt.ylabel("Number of instances")
plt.xlabel("Incident Category")
plt.show()

# %%
id_data["Primary Category"].value_counts().plot(kind="bar")
plt.title("Number of instances for each primary incident category")
plt.ylabel("Number of instances")
plt.xlabel("Primary Incident Category")
plt.show()

# %%
id_data["Incident Group"].value_counts()
# Out:
# Violence                       443
# Welfare                        273
# Emergency Situation            164
# Criminal Activity               49
# Malicious Use of Technology     48
# Weapon                          29
# Substances                      16
# Name: Incident Group, dtype: int64

# %%
id_data["Primary Category"].value_counts()
# Out:
# Assault                                251
# Indecent Assault                       130
# Student Welfare Concerns               107
# Attempted Suicide                       74
# Utility Failure                         72
# Student Behaviour                       60
# Bomb Threat                             49
# Allegations Of Sexual  Assault          47
# Nuisance Use of Technology              43
# Flood                                   40
# Self Harm                               32
# Possession of a Weapon                  29
# Police Operation                        22
# Severe Storm                            21
# Accidental Assault                      15
# Usage and Consumption of Substances     14
# Structural Fire                          7
# Sexting                                  5
# Bushfire                                 2
# Possession of a Substance                1
# Supply of a Substance                    1
# Name: Primary Category, dtype: int64

# %%
id_data["Primary Category"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
id_data["Incident Group"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
id_data["Incident Priority Rating"].plot()
# Out:
# <AxesSubplot:>
